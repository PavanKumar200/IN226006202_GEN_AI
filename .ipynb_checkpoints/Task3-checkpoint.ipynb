# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

model_name = "gpt2"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

print("Chatbot: Hello! I am GPT-2 chatbot. Type 'exit' to quit.")

chat_history_ids = None

while True:
    user_input = input("User: ")

    if user_input.lower() in ["exit", "quit"]:
        print("Chatbot: Goodbye!")
        break

    # Better prompt structure
    prompt = f"Answer the question clearly:\nQuestion: {user_input}\nAnswer:"

    inputs = tokenizer(prompt, return_tensors="pt")
    input_ids = inputs["input_ids"].to(device)

    # Append history
    if chat_history_ids is not None:
        bot_input_ids = torch.cat([chat_history_ids, input_ids], dim=-1)
    else:
        bot_input_ids = input_ids

    # Create attention mask
    attention_mask = torch.ones(bot_input_ids.shape, dtype=torch.long).to(device)

    # Generate response (FIXED SETTINGS)
    chat_history_ids = model.generate(
        bot_input_ids,
        attention_mask=attention_mask,
        max_new_tokens=60,
        pad_token_id=tokenizer.eos_token_id,
        do_sample=True,
        temperature=0.5,
        top_k=40,
        top_p=0.9,
        repetition_penalty=1.3,   # 🔥 prevents looping
        no_repeat_ngram_size=2    # 🔥 stops repetition
    )

    # Decode response
    bot_response = tokenizer.decode(
        chat_history_ids[:, bot_input_ids.shape[-1]:][0],
        skip_special_tokens=True
    )

    print("Chatbot:", bot_response.strip())
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Chatbot: Hello! I am GPT-2 chatbot. Type 'exit' to quit.
# User:  hello
# Chatbot: Hello, I'm a botchat client for the web. It works like this...
# User:  what is python
# Chatbot: Python has been around since at least 1997! This website will give you an idea of how it used to work and where we are today (we have no official documentation). Please follow along with us as well if possible so we can help keep our site relevant :) - The homepage also includes some other useful
# User:  What is Artificial Intelligence?
# Chatbot: AI's use in everyday life that was invented by humans over 500 years ago on Earth from insects or birds who were living within their own species' range.. They evolved into powerful machines capable easily controlling objects such people,...or animals they had never seen before.... So when one day human beings did something similar
# User:   Who created Python?
# Chatbot: We don't know but there may be another reason why many languages do not exist yet though user could say most others existed during those days User : Why didn`t your language develop until after World War II ? Well i think its simple because nobody knew about computers nor computer science anymore even then(they
# User:  thank you
# Chatbot: http://www3hc7p1yqk0f2r4b9j5vng6w8a/py-python "Py" does very good job explaining all kindsOf tools neededTo teach childrenPython 2 programming methodsFor teaching math using Pythagorean theorem
# User:   Who created Python?
# Chatbot: A few months back my brother went through learning Basic Lisp via Computer Science class he wanted me tooSo here comes his first attemptAt making funofall things which happened while playing games instead of doing anything elseBut just imagine trying different waysIt would take alot timeAnd effortThat only took 3 hoursSome
# User:  exit
# Chatbot: Goodbye!
